# %% [markdown]
# # <mobile_price 데이터 셋을 이용한 SVM 실습>
# ## 휴대폰의 여러가지 특성을 기반으로 가격 범위를 예측하는 분류 실습입니다.

# %% [markdown]
# 다음은 mobile_price.csv 데이터에 대한 설명 입니다.
#
# - battery_power: Total energy a battery can store in one time measured in mAh
# - blue: Has bluetooth or not
# - clock_speed: speed at which microprocessor executes instructions
# - dual_sim: Has dual sim support or not
# - fc: Front Camera mega pixels
# - four_g: Has 4G or not
# - int_memory: Internal Memory in Gigabytes
# - m_dep: Mobile Depth in cm
# - mobile_wt: Weight of mobile phone
# - n_cores: Number of cores of processor
# - pc: Primary Camera mega pixels
# - px_height: Pixel Resolution Height
# - px_width: Pixel Resolution Width
# - ram: Random Access Memory in Megabytes
# - sc_h: Screen Height of mobile in cm
# - sc_w: Screen Width of mobile in cm
# - talk_time: longest time that a single battery charge will last when you are
# - three_g: Has 3G or not
# - touch_screen: Has touch screen or not
# - wifi: Has wifi or not
#
# <br>
# 더 자세한 데이터 정보는 https://www.kaggle.com/iabhishekofficial/mobile-price-classification 에서 확인하시면 됩니다.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ### 1. mobile_price.csv 데이터 셋을 가져와서 처음 5개 행을 확인하시오.

# %%
price = pd.read_csv('mobile_price.csv')

price.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2. info() 함수를 이용해 데이터프레임의 기본 정보를 확인하시오.

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %% [markdown]
# ### 3. describe() 함수를 이용해 Target 칼럼 'price_range'의 정보를 확인하시오.

# %%
price['price_range'].describe()
# Out:
# count    2000.000000
# mean        1.500000
# std         1.118314
# min         0.000000
# 25%         0.750000
# 50%         1.500000
# 75%         2.250000
# max         3.000000
# Name: price_range, dtype: float64

# %% [markdown]
# ### 4. unique()함수를 이용해 Target 클래스의 종류를 확인하시오.

# %%
price['price_range'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %% [markdown]
# ### 5. 피처 간 상관관계를 분석하시오.

# %%
price_feat = price.drop('price_range', axis=1)
price_feat.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# px_width           -0.008402 -0.041533    -0.009476  0.014291 -0.005176
# ram                -0.000653  0.026351     0.003443  0.041072  0.015099
# sc_h               -0.029959 -0.002952    -0.029078 -0.011949 -0.011014
# sc_w               -0.021421  0.000613    -0.007378 -0.016666 -0.012373
# talk_time           0.052510  0.013934    -0.011432 -0.039404 -0.006829
# three_g             0.011522 -0.030236    -0.046433 -0.014008  0.001793
# touch_screen       -0.010516  0.010061     0.019756 -0.017117 -0.014828
# wifi               -0.008343 -0.021863    -0.024471  0.022740  0.020085
#
#                  four_g  int_memory     m_dep  mobile_wt   n_cores        pc  \
# battery_power  0.015665   -0.004004  0.034085   0.001844 -0.029727  0.031441
# blue           0.013443    0.041177  0.004049  -0.008605  0.036161 -0.009952
# clock_speed   -0.043073    0.006545 -0.014364   0.012350 -0.005724 -0.005245
# dual_sim       0.003187   -0.015679 -0.022142  -0.008979 -0.024658 -0.017143
# fc            -0.016560   -0.029133 -0.001791   0.023618 -0.013356  0.644595
# four_g         1.000000    0.008690 -0.001823  -0.016537 -0.029706 -0.005598
# int_memory     0.008690    1.000000  0.006886  -0.034214 -0.028310 -0.033273
# m_dep         -0.001823    0.006886  1.000000   0.021756 -0.003504  0.026282
# mobile_wt     -0.016537   -0.034214  0.021756   1.000000 -0.018989  0.018844
# n_cores       -0.029706   -0.028310 -0.003504  -0.018989  1.000000 -0.001193
# pc            -0.005598   -0.033273  0.026282   0.018844 -0.001193  1.000000
# px_height     -0.019236    0.010441  0.025263   0.000939 -0.006872 -0.018465
# px_width       0.007448   -0.008335  0.023566   0.000090  0.024480  0.004196
# ram            0.007313    0.032813 -0.009434  -0.002581  0.004868  0.028984
# sc_h           0.027166    0.037771 -0.025348  -0.033855 -0.000315  0.004938
# sc_w           0.037005    0.011731 -0.018388  -0.020761  0.025826 -0.023819
# talk_time     -0.046628   -0.002790  0.017003   0.006209  0.013148  0.014657
# three_g        0.584246   -0.009366 -0.012065   0.001551 -0.014733 -0.001322
# touch_screen   0.016758   -0.026999 -0.002638  -0.014368  0.023774 -0.008742
# wifi          -0.017620    0.006993 -0.028353  -0.000409 -0.009964  0.005389
#
#                px_height  px_width       ram      sc_h      sc_w  talk_time  \
# battery_power   0.014901 -0.008402 -0.000653 -0.029959 -0.021421   0.052510
# blue           -0.006872 -0.041533  0.026351 -0.002952  0.000613   0.013934
# clock_speed    -0.014523 -0.009476  0.003443 -0.029078 -0.007378  -0.011432
# dual_sim       -0.020875  0.014291  0.041072 -0.011949 -0.016666  -0.039404
# fc             -0.009990 -0.005176  0.015099 -0.011014 -0.012373  -0.006829
# four_g         -0.019236  0.007448  0.007313  0.027166  0.037005  -0.046628
# int_memory      0.010441 -0.008335  0.032813  0.037771  0.011731  -0.002790
# m_dep           0.025263  0.023566 -0.009434 -0.025348 -0.018388   0.017003
# mobile_wt       0.000939  0.000090 -0.002581 -0.033855 -0.020761   0.006209
# n_cores        -0.006872  0.024480  0.004868 -0.000315  0.025826   0.013148
# pc             -0.018465  0.004196  0.028984  0.004938 -0.023819   0.014657
# px_height       1.000000  0.510664 -0.020352  0.059615  0.043038  -0.010645
# px_width        0.510664  1.000000  0.004105  0.021599  0.034699   0.006720
# ram            -0.020352  0.004105  1.000000  0.015996  0.035576   0.010820
# sc_h            0.059615  0.021599  0.015996  1.000000  0.506144  -0.017335
# sc_w            0.043038  0.034699  0.035576  0.506144  1.000000  -0.022821
# talk_time      -0.010645  0.006720  0.010820 -0.017335 -0.022821   1.000000
# three_g        -0.031174  0.000350  0.015795  0.012033  0.030941  -0.042688
# touch_screen    0.021891 -0.001628 -0.030455 -0.020023  0.012720   0.017196
# wifi            0.051824  0.030319  0.022669  0.025929  0.035423  -0.029504
#
#                 three_g  touch_screen      wifi
# battery_power  0.011522     -0.010516 -0.008343
# blue          -0.030236      0.010061 -0.021863
# clock_speed   -0.046433      0.019756 -0.024471
# dual_sim      -0.014008     -0.017117  0.022740
# fc             0.001793     -0.014828  0.020085
# four_g         0.584246      0.016758 -0.017620
# int_memory    -0.009366     -0.026999  0.006993
# m_dep         -0.012065     -0.002638 -0.028353
# mobile_wt      0.001551     -0.014368 -0.000409
# n_cores       -0.014733      0.023774 -0.009964
# pc            -0.001322     -0.008742  0.005389
# px_height     -0.031174      0.021891  0.051824
# px_width       0.000350     -0.001628  0.030319
# ram            0.015795     -0.030455  0.022669
# sc_h           0.012033     -0.020023  0.025929
# sc_w           0.030941      0.012720  0.035423
# talk_time     -0.042688      0.017196 -0.029504
# three_g        1.000000      0.013917  0.004316
# touch_screen   0.013917      1.000000  0.011917
# wifi           0.004316      0.011917  1.000000

# %%
import seaborn as sns

sns.heatmap(price_feat.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### 6. 데이터의 타깃 칼럼을 분리해, X_mobile과 y_mobile으로 저장하시오

# %%
X_mobile = price.drop(['price_range'], axis=1, inplace=False)
y_mobile = price['price_range']

# %% [markdown]
# ### 7. 피처에 대해 MinMaxScaler()를 이용해 스케일링을 진행하시오.

# %%
mmscaler = MinMaxScaler()
X_mobile = mmscaler.fit_transform(X_mobile)

# %% [markdown]
# ### 8. train_test_split를 사용하여 train 셋과 test 셋을 분리하시오
# - testset 의 size : 전체 데이터 셋의 20%
# - 각 set의 이름 : X_train, X_test, y_train, y_test
# - random_state = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X_mobile, y_mobile, test_size=0.2, random_state=42)

# %% [markdown]
# ### 9. 선형 SVC 모델 (kernel: linear, C: 20) 을 만들어 fit 시키시오.

# %%
svm_clf = SVC(kernel = "linear", C = 20)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=20, kernel='linear')

# %% [markdown]
# ### 10. cross_val_score(cv=5)를 이용하여 CV점수를 출력하고 그 평균값을 구하시오.

# %%
from sklearn.model_selection import cross_val_score

score = cross_val_score(svm_clf, X_train, y_train, cv=5)
score
# Out:
# array([0.95    , 0.9625  , 0.95    , 0.925   , 0.971875])

# %%
np.mean(score)
# Out:
# 0.9518749999999999

# %% [markdown]
# ### 11. 가우시안 RBF 커널을 사용해서 SVM 모델을 만들어 보시오. <br>그리고 지난 과제를 참고하여 GridSearchCV(cv=5)를 사용해서<br> Gamma와 C의 최적 파라미터를 찾고 best parameter, best score를 출력하시오.
#
# ```python
# params = {
#     'gamma':[.1, .25, .5, 1],
#     'C': [1,5,10,20,40,100]
# }
# ```

# %%
rbf_kernel_svm_clf = SVC(kernel="rbf")
rbf_kernel_svm_clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'gamma':[.1, .25, .5, 1],       
    'C': [1,5,10,20,40,100]
}

grid_search = GridSearchCV(rbf_kernel_svm_clf, cv=5, param_grid=params, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20, 40, 100],
#                          'gamma': [0.1, 0.25, 0.5, 1]},
#              scoring='accuracy')

# %%
grid_search.best_params_, grid_search.best_score_
# Out:
# ({'C': 10, 'gamma': 0.1}, 0.903125)

# %% [markdown]
# ### 12. 위에서 구한 최적 파라미터를 rbf 모델에 적용하여 테스트 데이터에 대한 최종 예측을 출력하시오.

# %%
best_rbf = grid_search.best_estimator_
y_pred = best_rbf.predict(X_test)
y_pred
# Out:
# array([0, 2, 1, 3, 1, 1, 1, 0, 3, 1, 0, 1, 2, 3, 2, 3, 3, 3, 1, 0, 0, 2,
#        0, 2, 0, 1, 3, 2, 2, 0, 0, 0, 3, 0, 1, 1, 2, 0, 3, 0, 1, 3, 2, 0,
#        2, 3, 2, 1, 3, 1, 3, 1, 0, 0, 1, 0, 1, 3, 0, 0, 1, 3, 3, 1, 0, 0,
#        3, 3, 1, 2, 2, 2, 0, 1, 2, 0, 1, 3, 2, 2, 3, 2, 1, 0, 1, 3, 1, 3,
#        3, 0, 3, 3, 2, 1, 3, 2, 2, 3, 1, 1, 0, 0, 1, 1, 0, 3, 2, 0, 1, 1,
#        0, 0, 3, 1, 3, 2, 3, 2, 0, 2, 1, 3, 2, 1, 3, 3, 0, 3, 0, 2, 3, 0,
#        2, 2, 0, 2, 1, 0, 1, 2, 3, 1, 3, 2, 0, 0, 0, 1, 2, 2, 3, 1, 1, 0,
#        2, 2, 0, 1, 0, 2, 2, 3, 3, 3, 1, 0, 0, 2, 2, 3, 3, 0, 0, 0, 3, 1,
#        1, 2, 1, 0, 0, 0, 0, 0, 3, 2, 0, 3, 0, 0, 0, 0, 1, 3, 3, 2, 0, 1,
#        1, 1, 1, 1, 2, 2, 2, 3, 1, 2, 0, 0, 0, 2, 1, 1, 3, 1, 0, 2, 1, 1,
#        3, 2, 3, 0, 0, 2, 1, 3, 0, 1, 2, 0, 2, 3, 1, 1, 1, 3, 3, 0, 2, 3,
#        2, 3, 0, 3, 1, 2, 3, 3, 2, 1, 1, 3, 3, 1, 3, 3, 3, 2, 3, 0, 2, 2,
#        2, 2, 3, 0, 1, 3, 2, 2, 2, 1, 0, 1, 0, 2, 3, 1, 3, 1, 1, 3, 1, 2,
#        0, 0, 3, 0, 1, 2, 3, 3, 3, 1, 0, 0, 1, 3, 3, 0, 1, 2, 2, 0, 3, 3,
#        2, 3, 1, 3, 2, 0, 2, 1, 2, 1, 0, 0, 0, 3, 3, 3, 1, 0, 1, 0, 2, 2,
#        3, 0, 3, 3, 2, 1, 3, 0, 0, 3, 1, 3, 2, 0, 1, 1, 1, 1, 1, 3, 1, 0,
#        0, 3, 3, 0, 3, 0, 0, 2, 0, 0, 1, 2, 2, 3, 0, 3, 2, 3, 3, 3, 3, 2,
#        1, 1, 0, 3, 1, 3, 3, 0, 2, 3, 2, 3, 3, 3, 1, 0, 2, 3, 0, 0, 2, 3,
#        2, 1, 1, 2], dtype=int64)

# %% [markdown]
# # <autoparts 데이터 셋을 이용한 SVM 실습2>
# ## 자동차 부품에 대한 데이터 특성을 기반으로 c_thickness값을 예측 하여 불량을 판단하는 회귀 실습입니다.

# %% [markdown]
# 다음은 autoparts.csv 데이터에 대한 설명 입니다.<br>
# 데이터에 대한 제공된 설명이 따로 없어, 데이터 예시를 표기하였습니다.
#
# - prod_date: 2014-05-01 오전 8:28:56
# - prod_no: 90784-76001 제품번호
# - prod_name: Oil Gasket	 제품 이름
# - degree: 	2
# - mold: 생산대기
# - prod: 생산
# - s_no: 892890
# - fix_time:  85.5
# - a_speed: 0.611
# - b_speed: 1.715
# - separation: 242.0
# - s_separation: 657.6
# - rate_terms: 95
# - mpa: 78.2
# - load_time: 18.1
# - highpressure_time: 58
# - c_thickness: 24.7

# %% [markdown]
# ### 1. autoparts.csv 데이터 셋을 'autoparts' 이름으로 가져와서 처음 5개 행을 확인하시오.
# (hint: 데이터 설명을 보면 데이터에 한글이 포함되어 있다. 한글 인코딩을 진행해야한다.)

# %%
autoparts = pd.read_csv('autoparts.csv',  encoding='CP949')
# 인코딩 없이 불러오면 에러가 뜸. 한글 인코딩='CP949'

# %%
autoparts.head()
# Out:
#                prod_date      prod_no   prod_name  degree  mold prod    s_no  \
# 0  2014-05-01 오전 8:28:56  90784-76001  Oil Gasket       2  생산대기   생산  892890
# 1  2014-05-01 오전 8:27:29  90784-76001  Oil Gasket       2  생산대기   생산  892889
# 2  2014-05-01 오전 8:26:04  90784-76001  Oil Gasket       2  생산대기   생산  892888
# 3  2014-05-01 오전 8:24:37  90784-76001  Oil Gasket       2  생산대기   생산  892887
# 4  2014-05-01 오전 8:23:11  90784-76001  Oil Gasket       2  생산대기   생산  892886
#
#    fix_time  a_speed  b_speed  separation  s_separation  rate_terms   mpa  \
# 0      85.5    0.611    1.715       242.0         657.6          95  78.2
# 1      86.2    0.606    1.708       244.7         657.1          95  77.9
# 2      86.0    0.609    1.715       242.7         657.5          95  78.0
# 3      86.1    0.610    1.718       241.9         657.3          95  78.2
# 4      86.1    0.603    1.704       242.5         657.3          95  77.9
#
#    load_time  highpressure_time  c_thickness
# 0       18.1                 58         24.7
# 1       18.2                 58         22.5
# 2       18.1                 82         24.1
# 3       18.1                 74         25.1
# 4       18.2                 56         24.5

# %% [markdown]
# 아래 코드는 데이터가 방대하여 저희가 1차적으로 전처리를 진행하였습니다. 실행해주시면 됩니다.

# %%
autoparts1=autoparts[autoparts['prod_no']=='90784-76001'] # 제품 번호가 90784-76001인 것만 다룸
autoparts2=autoparts1[autoparts1['c_thickness']<1000] # c_thickness 종속변수 #큰 이상치 제외

autoparts2=pd.DataFrame(autoparts2)
autoparts2.drop(['prod_date','prod_no','prod_name','degree','mold','prod','s_no'], axis=1, inplace=True) # 종속변수에 불필요한 column제거 

autoparts2
# Out:
#        fix_time  a_speed  b_speed  separation  s_separation  rate_terms   mpa  \
# 0          85.5    0.611    1.715       242.0         657.6          95  78.2
# 1          86.2    0.606    1.708       244.7         657.1          95  77.9
# 2          86.0    0.609    1.715       242.7         657.5          95  78.0
# 3          86.1    0.610    1.718       241.9         657.3          95  78.2
# 4          86.1    0.603    1.704       242.5         657.3          95  77.9
# ...         ...      ...      ...         ...           ...         ...   ...
# 34134      82.7    0.594    1.578       219.7         684.1          85  75.9
# 34135      82.7    0.597    1.577       220.3         682.1          84  75.9
# 34136      82.5    0.591    1.581       219.8         684.1          85  75.9
# 34137      82.5    0.588    1.584       229.7         673.9          85  75.9
# 34138      82.5    0.597    1.576       218.5         684.1          85  75.9
#
#        load_time  highpressure_time  c_thickness
# 0           18.1                 58         24.7
# 1           18.2                 58         22.5
# 2           18.1                 82         24.1
# 3           18.1                 74         25.1
# 4           18.2                 56         24.5
# ...          ...                ...          ...
# 34134       20.2                 68         19.9
# 34135       20.2                 72         21.3
# 34136       20.2                 72         19.8
# 34137       20.2                 69         20.1
# 34138       20.2                 69         21.1
#
# [21767 rows x 10 columns]

# %% [markdown]
# ### 2. c_thickness가 20개 미만이거나 32개 초과인 데이터는 불량을 의미한다.<br>불량 여부를 판단하는 칼럼 'y_faulty'를 추가하고 불량이면 1, 정상이면 0으로 나타내시오.

# %%
autoparts2['y_faulty'] = (autoparts2['c_thickness'] < 20) | (autoparts2['c_thickness'] > 32 )
autoparts2['y_faulty'] = autoparts2['y_faulty'].astype(int)

autoparts2.head()
# Out:
#    fix_time  a_speed  b_speed  separation  s_separation  rate_terms   mpa  \
# 0      85.5    0.611    1.715       242.0         657.6          95  78.2
# 1      86.2    0.606    1.708       244.7         657.1          95  77.9
# 2      86.0    0.609    1.715       242.7         657.5          95  78.0
# 3      86.1    0.610    1.718       241.9         657.3          95  78.2
# 4      86.1    0.603    1.704       242.5         657.3          95  77.9
#
#    load_time  highpressure_time  c_thickness  y_faulty
# 0       18.1                 58         24.7         0
# 1       18.2                 58         22.5         0
# 2       18.1                 82         24.1         0
# 3       18.1                 74         25.1         0
# 4       18.2                 56         24.5         0

# %% [markdown]
# ### 3. X_featurues와 y_target이라는 이름으로 독립변수와 종속변수를 분리하시오. (종속변수 = c_thickness)

# %%
X_features = autoparts2.drop(['c_thickness'], inplace=False, axis=1)
y_target = autoparts2['c_thickness']

# %% [markdown]
# ### 4. 사이킷런에서 train_test_split을 이용해 훈련세트와 테스트 세트를 분리하시오.<br>
# X_train,X_test,y_train,y_test 이란 이름으로 세트를 만들고 test_size=0.3,random_state=42 이라는 옵션 추가하세요.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.3, random_state=42)

# %% [markdown]
# ### 5. 사이킷런의 LinearSVR 모델을 불러온 후 아래 params로 GridSearchCV를 진행하여 최적의 파라미터를 찾으세요.<br>
#
# ```python
# 'epsilon': [0.1, 1, 2, 10, 100], 'C': [1,5,10,40,100]
# cv=5
# ```

# %%
from sklearn.svm import LinearSVR
import warnings
warnings.filterwarnings("ignore") # 결국 max_iter=10000000 이런 식으로 돌려보다가 warning sign 무시를 택했다.

svm_reg = LinearSVR() 

# 옵션을 제대로 설정하지 않아서 이렇게 뜨는 것 같다. max_iter를 늘리면 warning sign은 뜨지 않을 듯.
# 여기에서는 그냥 돌아갔는데, 아래 gridsearchCV에서도 그대로 놔두면 계속 warning sign이 떠서 임의로 조정해봄.
# 1번과 비교해 보았을 때, scaling 과정을 거치지 않았기 때문에, 그리고 적당한 옵션을 지정하지 않았기 때문에 warning sign이 뜨고 gridsearchCV가 오래 걸리는 듯.

svm_reg.fit(X_train, y_train)
# Out:
# LinearSVR()

# %%
from sklearn.model_selection import GridSearchCV

params={
    'epsilon': [0.1, 1, 2, 10, 100], 'C': [1,5,10,40,100]
}

grid = GridSearchCV(svm_reg, cv=5, param_grid=params, scoring = 'neg_mean_squared_error')

grid.fit(X_train, y_train)

grid.best_params_
# Out:
# {'C': 40, 'epsilon': 2}

# %% [markdown]
# 위에서 찾은 최적 파라미터를 LinearSVR모델에 적용해 fit한 후 X_test를 예측하여 prediction란 이름에 저장하시오.
# 그리고 이 모델의 RMSE를 출력하시오

# %%
from sklearn.metrics import mean_squared_error
best_svm_reg = grid.best_estimator_
best_svm_reg.fit(X_train, y_train)

prediction = best_svm_reg.predict(X_test)
rmse = mean_squared_error(y_test, prediction, squared=False)
rmse
# Out:
# 4.651264369245053

# %% [markdown]
# y_test와 prediction의 관계를 그래프로 나타내시오. 또한 x축과 y축에 label을 표현하시오.<br>
# 또한  y=x 그래프를 그리고 실제와 예측 간 오차를 확인하시오.

# %%
plt.figure(figsize=(8, 5))
plt.scatter(y_test, prediction)
plt.plot([0,60], [0,200], 'k--')
plt.xlabel('y_test')
plt.ylabel('prediction')
plt.show()

# %% [markdown]
# ### 6. 사이킷런의 SVR 모델을 불러온 후 아래 params로 예측을 진행하시오.
# - kernel: rbf
# - C: 50
# - epsilon: 0.1
#
# SVR모델에 적용해 fit한 후 X_test를 예측하여 y_predict란 이름에 저장하시오.
# 그리고 이 모델의 RMSE를 출력하시오.

# %%
from sklearn.svm import SVR

svm_reg2 = SVR(kernel = 'rbf', C = 50, epsilon = 0.1)
svm_reg2.fit(X_train, y_train)
y_predict = svm_reg2.predict(X_test)
rmse = mean_squared_error(y_test, y_predict, squared=False)
rmse
# Out:
# 2.046582338593784

# %% [markdown]
# y_test와 y_predict의 관계를 그래프로 나타내시오.

# %%
plt.figure(figsize=(8, 5))
plt.scatter(y_test, y_predict)
plt.xlabel('y_test')
plt.ylabel('y_predict')
plt.show()

# %% [markdown]
# y_predict가 20 미만이거나 32 초과인 데이터는 1, 아니면 0으로 분류하시오.
# 그리고 X_test 데이터 셋에 y_faulty_predict 칼럼으로 추가하시오.

# %%
y_faulty_predict = ((y_predict < 20) | (y_predict > 32))
y_faulty_predict = y_faulty_predict.astype(int)
y_faulty_predict = pd.Series(y_faulty_predict)
y_faulty_predict
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6526    0
# 6527    0
# 6528    0
# 6529    0
# 6530    0
# Length: 6531, dtype: int32

# %%
X_test['y_faulty_predict'] = pd.Series(y_faulty_predict)

X_test.head() # NaN값 처리는 어떻게 하는 게 좋을까... 삭제?
# Out:
#        fix_time  a_speed  b_speed  separation  s_separation  rate_terms   mpa  \
# 7907       86.7    0.605    1.674       251.3         651.7          80  78.1
# 8920       85.9    0.603    1.622       248.4         651.6          80  80.7
# 17544      81.0    0.656    1.768       190.0         711.7          87  73.4
# 33568      82.5    0.594    1.575       219.6         680.4          86  75.7
# 8616       92.0    0.596    1.599       247.6         651.5          80  79.8
#
#        load_time  highpressure_time  y_faulty  y_faulty_predict
# 7907        18.1                 64         0               NaN
# 8920        18.1                 65         0               NaN
# 17544       19.2                 66         0               NaN
# 33568       20.2                 70         0               NaN
# 8616        18.1                 63         0               NaN

# %% [markdown]
# ### 7. 5-6번 실습을 기반으로 LinearSVR과 SVR 모델을 비교하여 간단히 서술하시오.

# %% [markdown]
# 답 : LinearSVR과 SVR 중에서 SVR 모델의 성능이 더 좋은 것 같다.

# %% [markdown]
# ### 뽀너스: Decision boundary 예제
# 출처:  https://jeongmin-lee.tistory.com/87

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import mglearn
# %matplotlib inline

iris = load_iris()

# 시각화를 위해서 sepal length와 width만 사용한다.
x = iris['data'][:, [0,1]] # column 0과 1만 사용
y = iris['target']

# train 데이터 세트와 test 데이터 세트를 구성한다.
trainX, testX, trainY, testY = \
    train_test_split(x, y, test_size=0.2)

# SVM으로 Train 데이터 세트를 학습한다.
svm = SVC(kernel='linear')
svm.fit(trainX, trainY)

# 정확도를 계산한다.
print('학습용 데이터로 측정한 정확도 = %.2f' % svm.score(trainX, trainY))
print('시험용 데이터로 측정한 정확도 = %.2f' % svm.score(testX, testY))

# 시각화
plt.figure(figsize=(8, 5))
mglearn.plots.plot_2d_classification(svm, trainX, alpha=0.1)
mglearn.discrete_scatter(trainX[:,0], trainX[:,1], trainY)
plt.legend()
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.show()
# Out:
# 학습용 데이터로 측정한 정확도 = 0.78
# 시험용 데이터로 측정한 정확도 = 0.77
